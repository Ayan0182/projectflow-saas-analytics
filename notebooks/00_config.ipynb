# %%
import random
import pandas as pd
from datetime import datetime, timedelta

random.seed(42)

# %%
company_names = [
    "Nexora Technologies",
    "CloudMint Labs",
    "BrightStack Systems",
    "CodeSphere Tech",
    "DataSprint Solutions",
    "PixelForge Labs",
    "WorkNest Technologies",
    "ElevateSoft",
    "CoreVista Solutions",
    "TaskNova Systems"
]

# %%
industries = [
    "SaaS",
    "FinTech",
    "EdTech",
    "HealthTech",
    "HRTech",
    "E-commerce",
    "Cyber Security",
    "AI"
]

# %%
cities = {
    "Ahmedabad": "Gujarat",
    "Bengaluru": "Karnataka",
    "Mumbai": "Maharashtra",
    "Pune": "Maharashtra",
    "Hyderabad": "Telangana",
    "Chennai": "Tamil Nadu",
    "Delhi": "Delhi"
}

# %%
plans = [
    "Free",
    "Starter",
    "Pro",
    "Enterprise"
]
